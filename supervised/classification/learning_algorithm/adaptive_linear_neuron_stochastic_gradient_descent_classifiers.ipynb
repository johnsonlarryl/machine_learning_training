# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from learning_algorithm.algo.neuron import AdaptiveLinearStochasticGradientDescent
from learning_algorithm.viz.plot import plot_decision_regions

# %%
flowers = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                      header=None)

# %%
# select setosa and versicolor
y = flowers.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)

# %%
# extract sepal length and petal length
x = flowers.iloc[0:100, [0, 2]].values

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
ada1 = AdaptiveLinearStochasticGradientDescent(eta=.01, n_iter=10).fit(x, y)
ax[0].plot(range(1, len(ada1.cost_) + 1),
           np.log10(ada1.cost_), marker='o')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('log(Sum-squared-error)')
ax[0].set_title('Adaline - Learning rate 0.01')

ada2 = AdaptiveLinearStochasticGradientDescent(eta=.0001, n_iter=10).fit(x, y)
ax[1].plot(range(1, len(ada2.cost_) + 1),
           ada2.cost_, marker='o')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Sum-squared-error')
ax[1].set_title('Adaline - Learning rate 0.0001')
plt.show() # This is not needed as the plot shows anyway

# %%
# Use standardization feature scaling to give data a normalized distribution
x_std = np.copy(x)
x_std[:,0] = (x[:,0] - x[:,0].mean()) / x[:,0].std()
x_std[:,1] = (x[:,1] - x[:,1].mean()) / x[:,1].std()

# %%
ada3 = AdaptiveLinearStochasticGradientDescent(eta=.01, n_iter=15).fit(x_std, y)
plot_decision_regions(x_std, y, classifier=ada3)
plt.title('Adaline - Gradient Descent')
plt.xlabel('sepal length [standardized]')
plt.ylabel('petal length [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

plt.plot(range(1, len(ada3.cost_) + 1), ada3.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 ada3 = AdaptiveLinearStochasticGradientDescent(eta=.01, n_iter=15).fit(x_std, y)
# ----> 2 plot_decision_regions(x_std, y, classifier=ada3)
#       3 plt.title('Adaline - Gradient Descent')
#       4 plt.xlabel('sepal length [standardized]')
#
# File ~/Documents/workspaces/machine_learning_training/supervised/classification/learning_algorithm/learning_algorithm/viz/plot.py:22, in plot_decision_regions(X, y, classifier, resolution)
#      18 x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
#      19 xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
#      20                        np.arange(x2_min, x2_max, resolution))
# ---> 22 z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
#      23 z = z.reshape(xx1.shape)
#      25 plt.contourf(xx1, xx2, z, alpha=0.3, cmap=cmap)
#
# File ~/Documents/workspaces/machine_learning_training/supervised/classification/learning_algorithm/learning_algorithm/algo/neuron.py:279, in AdaptiveLinearStochasticGradientDescent.predict(self, x)
#     267 def predict(self, x: np.ndarray) -> np.ndarray:
#     268     """
#     269     Return class label after unit step
#     270
#    (...)
#     277     :return: {array-like}, shape = [n_samples, n_features]
#     278     """
# --> 279     return np.where(self.activation(self.net_input(x) >= 0.0, 1, -1))
#
# TypeError: activation() takes 1 positional argument but 3 were given
